# %%
from pyhessian import hessian #import specific libraries, use pip install pyhessian

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
#standard python imports

# %%
def spatial_hessian_descent(n, dimensionality, subset):
  #takes in the step size N as a float value
  #the dimensionality of the data
  #the subset of
  for i in range[ceil(1/n)]:

    top_eigenvalues, top_eigenvector = hessian_comp.eigenvalues() # top eigven and top eigen vector

# %%
#code to implement step size
